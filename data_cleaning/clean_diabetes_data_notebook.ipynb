# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar dataset
df_original = pd.read_csv('raw_diabetes_data_2015.csv')

# Visualizar dataset
df_original
# Out:
#         _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0          1.0     1.0  b'01292015'  b'01'  b'29'  b'2015'    1200.0
# 1          1.0     1.0  b'01202015'  b'01'  b'20'  b'2015'    1100.0
# 2          1.0     1.0  b'02012015'  b'02'  b'01'  b'2015'    1200.0
# 3          1.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0
# 4          1.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0
# ...        ...     ...          ...    ...    ...      ...       ...
# 441451    72.0    11.0  b'12162015'  b'12'  b'16'  b'2015'    1100.0
# 441452    72.0    11.0  b'12142015'  b'12'  b'14'  b'2015'    1100.0
# 441453    72.0    11.0  b'12232015'  b'12'  b'23'  b'2015'    1200.0
# 441454    72.0    11.0  b'12152015'  b'12'  b'15'  b'2015'    1100.0
# 441455    72.0    11.0  b'12152015'  b'12'  b'15'  b'2015'    1100.0
#
#                SEQNO          _PSU  CTELENUM  ...  _PAREC1  _PASTAE1  \
# ...

# %%
# --- FUNCIONES DE LIMPIEZA Y TRANSFORMACIÓN ---

# -------------------------------
# FUNCIÓN GENÉRICA PARA VARIABLES BINARIAS
# -------------------------------
def codifica_variable_binaria(x, positivos, negativos):
    """
    Codifica variables categóricas en binario:
    - positivos: lista de valores que se codifican como 1
    - negativos: lista de valores que se codifican como 0
    Otros valores devuelven np.nan
    """
    if x in positivos:
        return 1
    elif x in negativos:
        return 0
    else:
        return np.nan
    
# -------------------------------
# FUNCIÓN PARA CONVERTIR FRECUENCIAS A VECES/DÍA
# -------------------------------
def convertir_a_veces_dia(valor):
    """
    Convierte códigos numéricos de frecuencia (p.ej. 101, 201, 301)
    en frecuencia diaria estimada:
    
    - 555 → 0 (nunca)
    - 777, 999, 300 → 0.01 veces/día (frecuencia muy baja)
    - 101-199 → valor - 100 (veces por día)
    - 201-299 → (valor - 200) / 7 (veces por semana → diario)
    - 301-399 → (valor - 300) / 30 (veces por mes → diario)
    - Otros valores → np.nan
    """
    if pd.isna(valor):
        return np.nan
    valor = int(valor)
    if valor == 555:
        return 0
    if valor in [777, 999, 300]:
        return 0.01
    if 101 <= valor <= 199:
        return valor - 100
    elif 201 <= valor <= 299:
        return (valor - 200) / 7
    elif 301 <= valor <= 399:
        return (valor - 300) / 30
    else:
        return np.nan

# -------------------------------
# FUNCIÓN PARA CONVERTIR FRECUENCIAS A RANGOS CUALITATIVOS
# -------------------------------
def convertir_a_rango(veces_dia):
    """
    Convierte frecuencia diaria a rangos cualitativos
    expresados en veces por semana:
    
    - ≥7 veces/semana → 1 (alta frecuencia)
    - 3-6.99 veces/semana → 2 (frecuencia media)
    - 1-2.99 veces/semana → 3 (frecuencia baja)
    - <1 vez/semana → 4 (muy baja o nunca)
    """
    if pd.isna(veces_dia):
        return np.nan
    veces_semana = veces_dia * 7
    if veces_semana >= 7:
        return 1
    elif veces_semana >= 3:
        return 2
    elif veces_semana >= 1:
        return 3
    else:
        return 4

# %%
# --- VARIABLES SELECCIONADAS ---

# Definición de las columnas a extraer del dataframe original
columnas_seleccionadas = [
    'DIABETE3',
    '_RFHYPE5', 'TOLDHI2', '_BMI5', 'SMOKE100',
    'CVDSTRK3', 'CVDCRHD4', 'EXERANY2', 'FRUIT1', 'VEGETAB1',
    'GENHLTH', 'PHYSHLTH', 'MENTHLTH', 'DIFFWALK', 'SEX',
    '_AGEG5YR', 'EDUCA', 'INCOME2', '_RACEGR3',  
    '_PA30021', '_PASTRNG'              
]

# Crear un dataframe nuevo con solo las columnas seleccionadas
df = df_original[columnas_seleccionadas].copy()

# Diccionario para renombrar columnas con nombres más descriptivos y legibles
mapa_renombrado = {
    'DIABETE3': 'estado_diabetes',
    '_RFHYPE5': 'presion_alta',
    'TOLDHI2': 'colesterol_alto',
    '_BMI5': 'bmi',
    'SMOKE100': 'fumo_100_cigs',
    'CVDSTRK3': 'historial_acv',
    'CVDCRHD4': 'historial_cardiaco',
    'EXERANY2': 'actividad_fisica',
    'FRUIT1': 'frutas_diarias',
    'VEGETAB1': 'verduras_diarias',
    'GENHLTH': 'salud_general',
    'PHYSHLTH': 'dias_mala_salud_fisica',
    'MENTHLTH': 'dias_mala_salud_mental',
    'DIFFWALK': 'dificultad_caminar',
    'SEX': 'sexo',
    '_AGEG5YR': 'grupo_edad',
    'EDUCA': 'nivel_educativo',
    'INCOME2': 'categoria_ingresos',
    '_RACEGR3': 'grupo_racial',
    '_PA30021': 'actividad_300_min ',
    '_PASTRNG': 'actividad_muscular',
}

# Aplicar renombrado de columnas
df.rename(columns=mapa_renombrado, inplace=True)

# -----------------------------
# CODIFICAR VARIABLES
# -----------------------------

# DIABETES
df['diabetes_bin'] = df['estado_diabetes'].apply(
    lambda x: codifica_variable_binaria(x, positivos=[1, 4], negativos=[2, 3])
)
df.drop(columns=['estado_diabetes'], inplace=True)

# HIPERTENSIÓN
df['presion_alta'] = df['presion_alta'].apply(
    lambda x: codifica_variable_binaria(x, positivos=[1, 4], negativos=[2, 3])
)

# COLESTEROL ALTO
df['colesterol_alto'] = df['colesterol_alto'].apply(
    lambda x: codifica_variable_binaria(x, positivos=[1, 4], negativos=[2, 3])
)

# Ajustar IMC (dividir entre 100 para escala decimal correcta)
df['bmi'] = df['bmi'] / 100

# FUMO 100 CIGS
df['fumo_100_cigs'] = df['fumo_100_cigs'].apply(
    lambda x: codifica_variable_binaria(x, positivos=[1], negativos=[2])
)

# HISTORIAL ACV
df['historial_acv'] = df['historial_acv'].apply(
    lambda x: codifica_variable_binaria(x, positivos=[1], negativos=[2])
)

# HISTORIAL CARDIACO
df['historial_cardiaco'] = df['historial_cardiaco'].apply(
    lambda x: codifica_variable_binaria(x, positivos=[1], negativos=[2])
)

# ACTIVIDAD FÍSICA
df['actividad_fisica'] = df['actividad_fisica'].apply(
    lambda x: codifica_variable_binaria(x, positivos=[1], negativos=[2])
)

# Frutas y verduras: convertir a rangos cualitativos
df['frecuencia_frutas'] = df['frutas_diarias'].apply(convertir_a_veces_dia).apply(convertir_a_rango)
df['frecuencia_verduras'] = df['verduras_diarias'].apply(convertir_a_veces_dia).apply(convertir_a_rango)

# Eliminar columnas originales de frutas y verduras
df.drop(columns=['frutas_diarias', 'verduras_diarias'], inplace=True)

# -------------------------------
# SALUD GENERAL
# -------------------------------
# Opcional: binarizar (buena vs. mala) o dejar ordinal
# Aquí solo limpiamos valores desconocidos o rechazados
df['salud_general'] = df['salud_general'].replace({
    7: np.nan,
    9: np.nan
})

# Si quieres binarizar:
# df['salud_general_bin'] = df['salud_general'].apply(
#     lambda x: 1 if x in [1, 2, 3] else (0 if x in [4, 5] else np.nan)
# )

# -------------------------------
# DÍAS MALA SALUD FÍSICA
# -------------------------------
df['dias_mala_salud_fisica'] = df['dias_mala_salud_fisica'].replace({
    88: 0,
    77: np.nan,
    99: np.nan
})

# -------------------------------
# DÍAS MALA SALUD MENTAL
# -------------------------------
df['dias_mala_salud_mental'] = df['dias_mala_salud_mental'].replace({
    88: 0,
    77: np.nan,
    99: np.nan
})

# -------------------------------
# DIFICULTAD CAMINAR
# -------------------------------
df['dificultad_caminar'] = df['dificultad_caminar'].apply(
    lambda x: codifica_variable_binaria(x, positivos=[1], negativos=[2])
)

# -------------------------------
# SEXO
# -------------------------------
df['sexo'] = df['sexo'].apply(lambda x: 1 if x == 1 else (0 if x == 2 else np.nan))

# -------------------------------
# GRUPO EDAD
# -------------------------------
df['grupo_edad'] = df['grupo_edad'].replace({
    14: np.nan
})

# -------------------------------
# NIVEL EDUCATIVO
# -------------------------------
df['nivel_educativo'] = df['nivel_educativo'].replace({
    9: np.nan
})

# -------------------------------
# CATEGORÍA INGRESOS
# -------------------------------
df['categoria_ingresos'] = df['categoria_ingresos'].replace({
    77: np.nan,
    99: np.nan
})

# -------------------------------
# OPCIONAL: agrupar ingresos en bajo, medio, alto
# -------------------------------
df['ingresos_grupo'] = df['categoria_ingresos'].apply(
    lambda x: 1 if x in [1, 2, 3] else
              2 if x in [4, 5] else
              3 if x in [6, 7, 8] else np.nan
)

# -------------------------------
# GRUPO RACIAL
# -------------------------------
df['grupo_racial'] = df['grupo_racial'].replace({
    9: 6   # agrupar unknown en "Other"
})

# -------------------------------
# ACTIVIDAD 300 MIN
# -------------------------------
df['actividad_300_min '] = df['actividad_300_min '].apply(
    lambda x: 1 if x == 1 else (0 if x == 2 else np.nan)
)

# -------------------------------
# ACTIVIDAD MUSCULAR
# -------------------------------
df['actividad_muscular'] = df['actividad_muscular'].apply(
    lambda x: 1 if x == 1 else (0 if x == 2 else np.nan)
)

print('\nTotal instancias: ', df.count())
print('\n\nNulos por columna: ')
print(df.isna().sum())
# Filas sin ningún valor nulo
total_sin_nulos = df.dropna().shape[0]

print('\n\nTotal instancias sin nulos:', total_sin_nulos)
# Out:
# Total instancias:  presion_alta              440089
# colesterol_alto           378741
# bmi                       405058
# fumo_100_cigs             423907
# historial_acv             440166
# historial_cardiaco        437639
# actividad_fisica          403464
# salud_general             440209
# dias_mala_salud_fisica    431713
# dias_mala_salud_mental    434048
# dificultad_caminar        426862
# sexo                      441456
# grupo_edad                436120
# nivel_educativo           439645
# categoria_ingresos        361951
# grupo_racial              441456
# actividad_300_min           385561
# actividad_muscular        397443
# diabetes_bin              440658
# frecuencia_frutas         412306
# frecuencia_verduras       408318
# ingresos_grupo            361951
# dtype: int64
#
#
# Nulos por columna:
# presion_alta               1367
# colesterol_alto           62715
# bmi                       36398
# fumo_100_cigs             17549
# ...

# %%
# -------------------------------------------------------
# IMPUTACIÓN DE VARIABLES CON VALORES FALTANTES
# -------------------------------------------------------

# -------------------------------------------
# 1. presion_alta (binaria: 0/1)
# Imputamos con la moda (valor más frecuente)
moda_presion = df['presion_alta'].mode()[0]
df['presion_alta'] = df['presion_alta'].fillna(moda_presion)

# -------------------------------------------
# 2. colesterol_alto (binaria: 0/1)
# Imputamos con la moda
moda_colesterol = df['colesterol_alto'].mode()[0]
df['colesterol_alto'] = df['colesterol_alto'].fillna(moda_colesterol)

# -------------------------------------------
# 3. fumo_100_cigs (binaria: 0/1)
# Imputamos con la moda
moda_fumo = df['fumo_100_cigs'].mode()[0]
df['fumo_100_cigs'] = df['fumo_100_cigs'].fillna(moda_fumo)

# -------------------------------------------
# 4. historial_acv (binaria: 0/1)
# Imputamos con la moda
moda_acv = df['historial_acv'].mode()[0]
df['historial_acv'] = df['historial_acv'].fillna(moda_acv)

# -------------------------------------------
# 5. historial_cardiaco (binaria: 0/1)
# Imputamos con la moda
moda_cardio = df['historial_cardiaco'].mode()[0]
df['historial_cardiaco'] = df['historial_cardiaco'].fillna(moda_cardio)

# -------------------------------------------
# 6. salud_general (ordinal: 1-5)
# Imputamos con la moda
moda_salud = df['salud_general'].mode()[0]
df['salud_general'] = df['salud_general'].fillna(moda_salud)

# -------------------------------------------
# 7. dias_mala_salud_fisica (0-30)
# Imputamos con la mediana porque es conteo y puede tener outliers
mediana_fisica = df['dias_mala_salud_fisica'].median()
df['dias_mala_salud_fisica'] = df['dias_mala_salud_fisica'].fillna(mediana_fisica)

# -------------------------------------------
# 8. dias_mala_salud_mental (0-30)
# Imputamos con la mediana
mediana_mental = df['dias_mala_salud_mental'].median()
df['dias_mala_salud_mental'] = df['dias_mala_salud_mental'].fillna(mediana_mental)

# -------------------------------------------
# 9. dificultad_caminar (binaria: 0/1)
# Imputamos con la moda
moda_caminar = df['dificultad_caminar'].mode()[0]
df['dificultad_caminar'] = df['dificultad_caminar'].fillna(moda_caminar)

# -------------------------------------------
# 10. grupo_edad (ordinal: 1-13)
# Imputamos con la moda
moda_edad = df['grupo_edad'].mode()[0]
df['grupo_edad'] = df['grupo_edad'].fillna(moda_edad)

# -------------------------------------------
# 11. nivel_educativo (ordinal: 1-6)
# Imputamos con la moda
moda_educa = df['nivel_educativo'].mode()[0]
df['nivel_educativo'] = df['nivel_educativo'].fillna(moda_educa)

# -------------------------------------------
# 12. categoria_ingresos (ordinal: 1-8)
# Imputamos con la moda
moda_ingresos = df['categoria_ingresos'].mode()[0]
df['categoria_ingresos'] = df['categoria_ingresos'].fillna(moda_ingresos)

# --------------------------------------------------
# NOTA: ingresos_grupo depende de categoria_ingresos
# Así que recalculamos ingresos_grupo:
# Bajo = 1-3, Medio = 4-5, Alto = 6-8
# --------------------------------------------------
df['ingresos_grupo'] = df['categoria_ingresos'].apply(
    lambda x: 1 if x in [1,2,3] else
              2 if x in [4,5] else
              3 if x in [6,7,8] else np.nan
)

# -------------------------------------------
# 13. frecuencia_frutas (ordinal: 1-4)
# Imputamos con la moda
moda_frutas = df['frecuencia_frutas'].mode()[0]
df['frecuencia_frutas'] = df['frecuencia_frutas'].fillna(moda_frutas)

# -------------------------------------------
# 14. frecuencia_verduras (ordinal: 1-4)
# Imputamos con la moda
moda_verduras = df['frecuencia_verduras'].mode()[0]
df['frecuencia_verduras'] = df['frecuencia_verduras'].fillna(moda_verduras)

# --------------------------------------------------
# Recalcular ingresos_grupo tras imputar ingresos
# Bajo = 1-3, Medio = 4-5, Alto = 6-8
# --------------------------------------------------
df['ingresos_grupo'] = df['categoria_ingresos'].apply(
    lambda x: 1 if x in [1,2,3] else
              2 if x in [4,5] else
              3 if x in [6,7,8] else np.nan
)

# -------------------------------------------
# 15. Eliminar duplicados
df = df.drop_duplicates().reset_index(drop=True)

# -------------------------------------------
# 16. Eliminar filas con diabetes_bin nulo (target desconocido)
df = df[df['diabetes_bin'].notna()]

# -------------------------------------------
# 17. Eliminar filas con valores nulos en variables clave (bmi y actividad física)
# Porque estas columnas tienen muchos nulos y no se imputaron para evitar sesgo.
df = df.dropna(subset=['bmi', 'actividad_fisica', 'actividad_300_min ', 'actividad_muscular']).reset_index(drop=True)

# -------------------------------------------
# Guardar dataframe limpio a archivo CSV
df.to_csv('cleaned_diabetes_data_extended.csv', index=False)

# -------------------------------------------------------
# REVISAMOS QUE YA NO QUEDEN NULOS
# -------------------------------------------------------
print("\nValores nulos restantes después de imputar:")
print(df.isna().sum())
# Out:
# Valores nulos restantes después de imputar:
# presion_alta              0
# colesterol_alto           0
# bmi                       0
# fumo_100_cigs             0
# historial_acv             0
# historial_cardiaco        0
# actividad_fisica          0
# salud_general             0
# dias_mala_salud_fisica    0
# dias_mala_salud_mental    0
# dificultad_caminar        0
# sexo                      0
# grupo_edad                0
# nivel_educativo           0
# categoria_ingresos        0
# grupo_racial              0
# actividad_300_min           0
# actividad_muscular        0
# diabetes_bin              0
# frecuencia_frutas         0
# frecuencia_verduras       0
# ingresos_grupo            0
# dtype: int64
